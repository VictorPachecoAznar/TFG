# %% [markdown]
# PROMPTS DE BOUNDING BOX

# %%
import os
from samgeo import SamGeo
#from samgeo.text_sam import LangSAM

# %%
import sys
package=r'D:\VICTOR_PACHECO\CUARTO\PROCESADO_IMAGEN'
sys.path.insert(1,package)

# %%
from apb_spatial_computer_vision import BASE_DIR,DATA_DIR,STATIC_DIR,OUT_DIR,PACKAGE_DIR
import apb_spatial_computer_vision.raster_utilities

# %% [markdown]
# CREACIÓN DE UN MAPA BASE

# %%
import leafmap
m = leafmap.Map(center=[41.32180, 2.14312], zoom=15, height=700)
m.add_basemap("SATELLITE")

# %%
sam = SamGeo(
    model_type="vit_h",
    automatic=False,
    sam_kwargs=None,
)

# %%
boxes=os.path.join(OUT_DIR,'tanks_50c_40iou.geojson')

# %%
tile=apb_spatial_computer_vision.raster_utilities.Tile(r'D:\VICTOR_PACHECO\CUARTO\PROCESADO_IMAGEN\data\ORTO_ME_BCN_pyramid\subset_2\tile_4096_grid_2_2.tif')

# %%
images=tile.get_siblings()

# %%
for image in images:
    sam.set_image(image)
    sam.predict(boxes=boxes, point_crs="EPSG:25831", output=os.path.join(apb_spatial_computer_vision.raster_utilities.folder_check(os.path.join(OUT_DIR, 'sammed')), f"mask{count}.tif"), dtype="uint8")
    count+=1
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[11], line 3
#       1 count=0
#       2 for image in images:
# ----> 3     sam.set_image(image)
#       4     sam.predict(boxes=boxes, point_crs="EPSG:25831", output=os.path.join(package.raster_utilities.folder_check(os.path.join(OUT_DIR,'sammed')),f"mask{count}.tif"), dtype="uint8")
#       5     count+=1
#
# File c:\Users\FOTOGRAMETRIA\anaconda3\envs\clean_env_cuda\Lib\site-packages\samgeo\samgeo.py:471, in SamGeo.set_image(self, image, image_format)
#     468 else:
#     469     raise ValueError("Input image must be either a path or a numpy array.")
# --> 471 self.predictor.set_image(image, image_format=image_format)
#
# File c:\Users\FOTOGRAMETRIA\anaconda3\envs\clean_env_cuda\Lib\site-packages\segment_anything\predictor.py:60, in SamPredictor.set_image(self, image, image_format)
# ...

# %%
count=0
sam.set_image(images[0])
sam.predict(boxes=boxes, point_crs="EPSG:25831", output=os.path.join(apb_spatial_computer_vision.raster_utilities.folder_check(os.path.join(OUT_DIR, 'sammed')), f"mask{count}.tif"), dtype="uint8")
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[12], line 2
#       1 count=0
# ----> 2 sam.set_image(images[0])
#       3 sam.predict(boxes=boxes, point_crs="EPSG:25831", output=os.path.join(package.raster_utilities.folder_check(os.path.join(OUT_DIR,'sammed')),f"mask{count}.tif"), dtype="uint8")
#
# File c:\Users\FOTOGRAMETRIA\anaconda3\envs\clean_env_cuda\Lib\site-packages\samgeo\samgeo.py:471, in SamGeo.set_image(self, image, image_format)
#     468 else:
#     469     raise ValueError("Input image must be either a path or a numpy array.")
# --> 471 self.predictor.set_image(image, image_format=image_format)
#
# File c:\Users\FOTOGRAMETRIA\anaconda3\envs\clean_env_cuda\Lib\site-packages\segment_anything\predictor.py:60, in SamPredictor.set_image(self, image, image_format)
#      57 input_image_torch = torch.as_tensor(input_image, device=self.device)
# ...
